# %%
import numpy as np

# %%
tau=np.linspace(0,10,50)
plot(tau,tau/np.sqrt(1+tau*tau),'--',)
ylim([0,1.1])
grid()

# %%
# Out:
# array([ 1.        ,  0.97980406,  0.92584764,  0.8528513 ,  0.7746612 ,
#         0.69992858,  0.63253457,  0.57346234,  0.52231208,  0.47816827,
#         0.44001525,  0.40690882,  0.37803196,  0.35270058,  0.33035042,
#         0.31051865,  0.29282578,  0.27695995,  0.2626638 ,  0.24972388,
#         0.23796223,  0.22722962,  0.21740021,  0.20836731,  0.20004   ,
#         0.19234034,  0.18520127,  0.17856474,  0.17238033,  0.16660404,
#         0.16119729,  0.15612619,  0.15136078,  0.14687455,  0.14264391,
#         0.13864784,  0.13486755,  0.13128617,  0.12788852,  0.12466095,
#         0.12159108,  0.11866772,  0.1158807 ,  0.11322075,  0.11067944,
#         0.10824904,  0.10592249,  0.10369331,  0.10155555,  0.09950372])

# %%
np.power?

# %%
plot(tau,1/(1+np.exp(-tau*tau)),'--')
ylim([0,1.1])
grid()

# %%
plot(tau,np.exp(-tau*tau),'--')
ylim([0,1.1])
grid()
